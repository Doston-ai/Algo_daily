# %%
# o'rta qiymat (mean)
x = [2, 4, 6, 8, 10]
y = sum(x) / len(x)
print("O'rta qiymat:", y)
# Out:
# O'rta qiymat: 6.0

# %%
x = [2, 15, 6, 21, 10, 11]
for i in range(len(x)):
    for k in range(i, len(x)):
        if x[i]>x[k]:
            x[i], x[k] = x[k], x[i]
print(x)
# Out:
# [2, 6, 10, 11, 15, 21]

# %%
# median
x = [2, 4, 6, 8, 10, 11]
x.sort()
n = len(x)
if n % 2 == 0:
    median = (x[n//2 - 1] + x[n//2]) / 2
else:
    median = x[n//2]
print("Median:", median)
# Out:
# Median: 7.0

# %%
# mode
data = [2, 4, 6, 8, 8, 8, 10, 10] 
takror = {}

for i in data:
    if i not in takror:
        takror[i] = 1
    else:
        takror[i] += 1
max_count = max(takror.values())
# mode = [key for key, value in takror.items()  if value == max_count] # one line code
mode = []
for key, value in takror.items():
    if value == max_count:
        mode.append(key)

print("Lug'at >>>", takror)       
print("Max takrorlangan >>>", max_count) 
print("Moda >>>", mode)
# Out:
# Lug'at >>> {2: 1, 4: 1, 6: 1, 8: 3, 10: 2}
# Max takrorlangan >>> 3
# Moda >>> [8]

# %%
# dispersion    
x = [2, 4, 8, 6, 8, 10]
x.sort()
mean = sum(x) / len(x)
variance = sum((xi - mean) ** 2 for xi in x) / len(x)
print("Dispersion (Variance):", variance)
# Out:
# Dispersion (Variance): 7.222222222222222

# %%
# polygon of chastota
import matplotlib.pyplot as plt
import seaborn as sns

values = [2, 4,6, 8, 10]
frequencies = [5,1,3,1, 4]
plt.plot(values, frequencies)
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.title("Polygon of Chastota")
plt.show()

# %%
x = [2, 4, 4, 4, 6 ,6, 8, 8, 8, 10]
plt.hist(x, bins=5, edgecolor='black', facecolor='lightblue')
plt.title('Gistogramma')
plt.xlabel('Qiymatlar')
plt.ylabel('Chastota')
plt.show()
