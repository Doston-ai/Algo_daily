# %%
# pip install yt-dlp

# %%
import yt_dlp

def download_video(url):
    ydl_opts = {
        'format': 'bestvideo+bestaudio/best', # Best quality available
        'outtmpl': '%(title)s.%(ext)s',      # Save file as "Video Title.mp4"
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])

video_url = input("Enter the YouTube URL: ")
download_video(video_url)
